# %%
import tensorflow as tf

INPUT_NODE = 784
OUTPUT_NODE = 10
LAYER1_NODE = 500

def get_weight(shape, regularizer):
    w = tf.Variable(tf.truncated_normal(shape,stddev=0.1))
    if regularizer != None: tf.add_to_collection('losses', tf.contrib.layers.l2_regularizer(regularizer)(w))
    return w

def get_bias(shape):  
    b = tf.Variable(tf.zeros(shape))  
    return b

def forward(x, regularizer):
    w1 = get_weight([INPUT_NODE, LAYER1_NODE], regularizer)
    b1 = get_bias([LAYER1_NODE])
    y1 = tf.nn.relu(tf.matmul(x, w1) + b1)

    w2 = get_weight([LAYER1_NODE, OUTPUT_NODE], regularizer)
    b2 = get_bias([OUTPUT_NODE])
    y = tf.matmul(y1, w2) + b2
    return y

# %%
from tensorflow.examples.tutorials.mnist import input_data
import mnist_forward
import os

BATCH_SIZE = 200
LEARNING_RATE_BASE = 0.1
LEARNING_RATE_DECAY = 0.99
REGULARIZER = 0.0001
STEPS = 50000
MOVING_AVERAGE_DECAY = 0.99
MODEL_SAVE_PATH="./model/"
MODEL_NAME="mnist_model"


def backward(mnist):

    x = tf.placeholder(tf.float32, [None, mnist_forward.INPUT_NODE])
    y_ = tf.placeholder(tf.float32, [None, mnist_forward.OUTPUT_NODE])
    y = mnist_forward.forward(x, REGULARIZER)
    global_step = tf.Variable(0, trainable=False)

    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y, labels=tf.argmax(y_, 1))
    cem = tf.reduce_mean(ce)
    loss = cem + tf.add_n(tf.get_collection('losses'))

    learning_rate = tf.train.exponential_decay(
        LEARNING_RATE_BASE,
        global_step,
        mnist.train.num_examples / BATCH_SIZE, 
        LEARNING_RATE_DECAY,
        staircase=True)

    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    ema = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY, global_step)
    ema_op = ema.apply(tf.trainable_variables())
    with tf.control_dependencies([train_step, ema_op]):
        train_op = tf.no_op(name='train')

    saver = tf.train.Saver()

    with tf.Session() as sess:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)

        for i in range(STEPS):
            xs, ys = mnist.train.next_batch(BATCH_SIZE)
            _, loss_value, step = sess.run([train_op, loss, global_step], feed_dict={x: xs, y_: ys})
            if i % 1000 == 0:
                print("After %d training step(s), loss on training batch is %g." % (step, loss_value))
                saver.save(sess, os.path.join(MODEL_SAVE_PATH, MODEL_NAME), global_step=global_step)


def main():
    mnist = input_data.read_data_sets("./data/", one_hot=True)
    backward(mnist)

if __name__ == '__main__':
    main()
# Out:
# Extracting ./data/train-images-idx3-ubyte.gz
# Extracting ./data/train-labels-idx1-ubyte.gz
# Extracting ./data/t10k-images-idx3-ubyte.gz
# Extracting ./data/t10k-labels-idx1-ubyte.gz
# After 1 training step(s), loss on training batch is 3.261.
# After 1001 training step(s), loss on training batch is 0.385523.
# After 2001 training step(s), loss on training batch is 0.266589.
# After 3001 training step(s), loss on training batch is 0.225156.
# After 4001 training step(s), loss on training batch is 0.244095.
# After 5001 training step(s), loss on training batch is 0.224954.
# After 6001 training step(s), loss on training batch is 0.191346.
# After 7001 training step(s), loss on training batch is 0.188262.
# After 8001 training step(s), loss on training batch is 0.185701.
# After 9001 training step(s), loss on training batch is 0.193983.
# After 10001 training step(s), loss on training batch is 0.202058.
# After 11001 training step(s), loss on training batch is 0.172047.
# After 12001 training step(s), loss on training batch is 0.161266.
# After 13001 training step(s), loss on training batch is 0.16838.
# After 14001 training step(s), loss on training batch is 0.164268.
# After 15001 training step(s), loss on training batch is 0.166966.
# After 16001 training step(s), loss on training batch is 0.155112.
# After 17001 training step(s), loss on training batch is 0.153086.
# After 18001 training step(s), loss on training batch is 0.148249.
# After 19001 training step(s), loss on training batch is 0.147754.
# After 20001 training step(s), loss on training batch is 0.149687.
# After 21001 training step(s), loss on training batch is 0.142867.
# After 22001 training step(s), loss on training batch is 0.144109.
# After 23001 training step(s), loss on training batch is 0.150633.
# After 24001 training step(s), loss on training batch is 0.144385.
# After 25001 training step(s), loss on training batch is 0.14423.
# After 26001 training step(s), loss on training batch is 0.144246.
# After 27001 training step(s), loss on training batch is 0.134479.
# After 28001 training step(s), loss on training batch is 0.141034.
# After 29001 training step(s), loss on training batch is 0.13232.
# After 30001 training step(s), loss on training batch is 0.134752.
# After 31001 training step(s), loss on training batch is 0.134845.
# After 32001 training step(s), loss on training batch is 0.138381.
# After 33001 training step(s), loss on training batch is 0.139131.
# After 34001 training step(s), loss on training batch is 0.132464.
# After 35001 training step(s), loss on training batch is 0.137544.
# After 36001 training step(s), loss on training batch is 0.129808.
# After 37001 training step(s), loss on training batch is 0.137218.
# After 38001 training step(s), loss on training batch is 0.127441.
# After 39001 training step(s), loss on training batch is 0.133973.
# After 40001 training step(s), loss on training batch is 0.130277.
# After 41001 training step(s), loss on training batch is 0.130777.
# After 42001 training step(s), loss on training batch is 0.129565.
# After 43001 training step(s), loss on training batch is 0.122972.

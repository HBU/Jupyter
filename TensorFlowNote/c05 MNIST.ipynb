# %%
import tensorflow as tf

INPUT_NODE = 784
OUTPUT_NODE = 10
LAYER1_NODE = 500

def get_weight(shape, regularizer):
    w = tf.Variable(tf.truncated_normal(shape,stddev=0.1))
    if regularizer != None: tf.add_to_collection('losses', tf.contrib.layers.l2_regularizer(regularizer)(w))
    return w

def get_bias(shape):  
    b = tf.Variable(tf.zeros(shape))  
    return b

def forward(x, regularizer):
    w1 = get_weight([INPUT_NODE, LAYER1_NODE], regularizer)
    b1 = get_bias([LAYER1_NODE])
    y1 = tf.nn.relu(tf.matmul(x, w1) + b1)

    w2 = get_weight([LAYER1_NODE, OUTPUT_NODE], regularizer)
    b2 = get_bias([OUTPUT_NODE])
    y = tf.matmul(y1, w2) + b2
    return y

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import mnist_forward
import os

BATCH_SIZE = 200
LEARNING_RATE_BASE = 0.1
LEARNING_RATE_DECAY = 0.99
REGULARIZER = 0.0001
STEPS = 50000
MOVING_AVERAGE_DECAY = 0.99
MODEL_SAVE_PATH="./model/"
MODEL_NAME="mnist_model"


def backward(mnist):

    x = tf.placeholder(tf.float32, [None, mnist_forward.INPUT_NODE])
    y_ = tf.placeholder(tf.float32, [None, mnist_forward.OUTPUT_NODE])
    y = mnist_forward.forward(x, REGULARIZER)
    global_step = tf.Variable(0, trainable=False)

    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y, labels=tf.argmax(y_, 1))
    cem = tf.reduce_mean(ce)
    loss = cem + tf.add_n(tf.get_collection('losses'))

    learning_rate = tf.train.exponential_decay(
        LEARNING_RATE_BASE,
        global_step,
        mnist.train.num_examples / BATCH_SIZE, 
        LEARNING_RATE_DECAY,
        staircase=True)

    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    ema = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY, global_step)
    ema_op = ema.apply(tf.trainable_variables())
    with tf.control_dependencies([train_step, ema_op]):
        train_op = tf.no_op(name='train')

    saver = tf.train.Saver()

    with tf.Session() as sess:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)

        for i in range(STEPS):
            xs, ys = mnist.train.next_batch(BATCH_SIZE)
            _, loss_value, step = sess.run([train_op, loss, global_step], feed_dict={x: xs, y_: ys})
            if i % 1000 == 0:
                print("After %d training step(s), loss on training batch is %g." % (step, loss_value))
                saver.save(sess, os.path.join(MODEL_SAVE_PATH, MODEL_NAME), global_step=global_step)


def main():
    mnist = input_data.read_data_sets("./data/", one_hot=True)
    backward(mnist)

if __name__ == '__main__':
    main()
# Out:
# Extracting ./data/train-images-idx3-ubyte.gz
# Extracting ./data/train-labels-idx1-ubyte.gz
# Extracting ./data/t10k-images-idx3-ubyte.gz
# Extracting ./data/t10k-labels-idx1-ubyte.gz
# After 1 training step(s), loss on training batch is 2.93968.
# After 1001 training step(s), loss on training batch is 0.362526.
# After 2001 training step(s), loss on training batch is 0.275845.
# After 3001 training step(s), loss on training batch is 0.253223.
# After 4001 training step(s), loss on training batch is 0.224748.
# After 5001 training step(s), loss on training batch is 0.258538.
# After 6001 training step(s), loss on training batch is 0.199807.
# After 7001 training step(s), loss on training batch is 0.189871.
# After 8001 training step(s), loss on training batch is 0.189725.
# After 9001 training step(s), loss on training batch is 0.165151.
# After 10001 training step(s), loss on training batch is 0.16981.
# After 11001 training step(s), loss on training batch is 0.186277.
# After 12001 training step(s), loss on training batch is 0.166982.
# After 13001 training step(s), loss on training batch is 0.169698.
# After 14001 training step(s), loss on training batch is 0.15501.
# After 15001 training step(s), loss on training batch is 0.171498.
# After 16001 training step(s), loss on training batch is 0.147773.
# After 17001 training step(s), loss on training batch is 0.141439.
# After 18001 training step(s), loss on training batch is 0.176824.
# After 19001 training step(s), loss on training batch is 0.156776.
# After 20001 training step(s), loss on training batch is 0.156961.
# After 21001 training step(s), loss on training batch is 0.147162.
# After 22001 training step(s), loss on training batch is 0.139656.
# After 23001 training step(s), loss on training batch is 0.145593.
# After 24001 training step(s), loss on training batch is 0.137465.
# After 25001 training step(s), loss on training batch is 0.143584.
# After 26001 training step(s), loss on training batch is 0.138204.
# After 27001 training step(s), loss on training batch is 0.138931.
# After 28001 training step(s), loss on training batch is 0.140759.
# After 29001 training step(s), loss on training batch is 0.134192.
# After 30001 training step(s), loss on training batch is 0.131587.
# After 31001 training step(s), loss on training batch is 0.142204.
# After 32001 training step(s), loss on training batch is 0.137908.
# After 33001 training step(s), loss on training batch is 0.131898.
# After 34001 training step(s), loss on training batch is 0.130141.
# After 35001 training step(s), loss on training batch is 0.130004.
# After 36001 training step(s), loss on training batch is 0.132483.
# After 37001 training step(s), loss on training batch is 0.132573.
# After 38001 training step(s), loss on training batch is 0.13157.
# After 39001 training step(s), loss on training batch is 0.12918.
# After 40001 training step(s), loss on training batch is 0.13276.
# After 41001 training step(s), loss on training batch is 0.129858.
# After 42001 training step(s), loss on training batch is 0.127111.
# After 43001 training step(s), loss on training batch is 0.125959.
# After 44001 training step(s), loss on training batch is 0.129236.
# After 45001 training step(s), loss on training batch is 0.131612.
# After 46001 training step(s), loss on training batch is 0.12596.
# After 47001 training step(s), loss on training batch is 0.129257.
# After 48001 training step(s), loss on training batch is 0.120533.
# After 49001 training step(s), loss on training batch is 0.128498.

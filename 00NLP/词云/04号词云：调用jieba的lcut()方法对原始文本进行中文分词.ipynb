# %%
import jieba
import wordcloud
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# 构建并配置词云对象w
w = wordcloud.WordCloud(width=1000,height=700,background_color='white',font_path='msyh.ttc')

# %%
txt = '同济大学（Tongji University），简称“同济”，是中华人民共和国教育部直属，由教育部、国家海洋局和上海市共建的全国重点大学，历史悠久、声誉卓著，是国家“双一流”、“211工程”、“985工程”重点建设高校，也是收生标准最严格的中国大学之一'

# %%
w.generate(txt)
w.to_file('WordClouds/output4-tongji.png')
img=Image.open('WordClouds/output4-tongji.png')
m=np.asarray(img)
plt.imshow(m)

# %% [markdown]
# # 调用jieba的lcut()方法对原始文本进行中文分词，得到string

# %%
txtlist = jieba.lcut(txt)
string = " ".join(txtlist)

# 将string变量传入w的generate()方法，给词云输入文字
w.generate(string)

# 将词云图片导出到当前文件夹
w.to_file('WordClouds/output4-jieba.png')
img=Image.open('WordClouds/output4-jieba.png')
m=np.asarray(img)
plt.imshow(m)

# %%
print(txt)
print(txtlist)
# Out:
# 同济大学（Tongji University），简称“同济”，是中华人民共和国教育部直属，由教育部、国家海洋局和上海市共建的全国重点大学，历史悠久、声誉卓著，是国家“双一流”、“211工程”、“985工程”重点建设高校，也是收生标准最严格的中国大学之一
# ['同济大学', '（', 'Tongji', ' ', 'University', '）', '，', '简称', '“', '同济', '”', '，', '是', '中华人民共和国教育部', '直属', '，', '由', '教育部', '、', '国家海洋局', '和', '上海市', '共建', '的', '全国', '重点', '大学', '，', '历史悠久', '、', '声誉卓著', '，', '是', '国家', '“', '双', '一流', '”', '、', '“', '211', '工程', '”', '、', '“', '985', '工程', '”', '重点', '建设', '高校', '，', '也', '是', '收生', '标准', '最', '严格', '的', '中国大学', '之一']

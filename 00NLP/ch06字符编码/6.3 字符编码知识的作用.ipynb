# %% [markdown]
# # 1. 便于表示控制字符
#
# 回车，ASCII码13
#
# 换行，ASCII码10
#
# 空格，ASCII码32

# %%
print("10位ASCII码转为字符：",  chr(13))
# Out:
# 10位ASCII码转为字符：

# %%
str = input("请输入：");
if (str == chr(32)):
    print ("你输入的内容是: 空格")
else:
    print ("你输入的内容是: ", str)
# Out:
# 请输入：
# 你输入的内容是: 空格

# %% [markdown]
# # 2. 编程中对字符分类

# %% [markdown]
# ord() 返回对应的 ASCII 数值，或者 Unicode 数值

# %%
str = input("请输入：");
if (ord(str) < 128):
    print ("你输入的内容是: 西文字符")
elif(ord(str) >= 176):
    print ("你输入的内容是: 中文字符")
else:
    print ("你输入的内容是: 其他字符")
# Out:
# 请输入：3
# 你输入的内容是: 西文字符

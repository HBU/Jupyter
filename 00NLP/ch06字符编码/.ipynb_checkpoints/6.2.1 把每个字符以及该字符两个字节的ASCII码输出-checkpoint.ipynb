# %%
for i in range(161,254):
    for j in range(161,254):
        s = hex(i) + hex(j)
        s = s.replace('0x','')
        bi = [int(s[0:2],16),]
        bi = bi + [int(s[2:4],16),]
        bs = bytearray(bi)
        print(bytes(bs).decode('gb18030'),i,j,'  ',end='')
        if j==9:
            print('\n')
# Out:
# 　 161 161   、 161 162   。 161 163   · 161 164   ˉ 161 165   ˇ 161 166   ¨ 161 167   〃 161 168   々 161 169   — 161 170   ～ 161 171   ‖ 161 172   … 161 173   ‘ 161 174   ’ 161 175   “ 161 176   ” 161 177   〔 161 178   〕 161 179   〈 161 180   〉 161 181   《 161 182   》 161 183   「 161 184   」 161 185   『 161 186   』 161 187   〖 161 188   〗 161 189   【 161 190   】 161 191   ± 161 192   × 161 193   ÷ 161 194   ∶ 161 195   ∧ 161 196   ∨ 161 197   ∑ 161 198   ∏ 161 199   ∪ 161 200   ∩ 161 201   ∈ 161 202   ∷ 161 203   √ 161 204   ⊥ 161 205   ∥ 161 206   ∠ 161 207   ⌒ 161 208   ⊙ 161 209   ∫ 161 210   ∮ 161 211   ≡ 161 212   ≌ 161 213   ≈ 161 214   ∽ 161 215   ∝ 161 216   ≠ 161 217   ≮ 161 218   ≯ 161 219   ≤ 161 220   ≥ 161 221   ∞ 161 222   ∵ 161 223   ∴ 161 224   ♂ 161 225   ♀ 161 226   ° 161 227   ′ 161 228   ″ 161 229   ℃ 161 230   ＄ 161 231   ¤ 161 232   ￠ 161 233   ￡ 161 234   ‰ 161 235   § 161 236   № 161 237   ☆ 161 238   ★ 161 239   ○ 161 240   ● 161 241   ◎ 161 242   ◇ 161 243   ◆ 
# ...

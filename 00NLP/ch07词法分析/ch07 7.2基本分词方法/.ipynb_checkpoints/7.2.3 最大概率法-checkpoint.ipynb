# %% [markdown]
# https://blog.csdn.net/chase1998/article/details/83247192

# %%
def load_dict():
    """
    加载字典
    :return:返回字典==>"词:频率"
    """
    dic_file = open("WordFrequency.txt", 'r', encoding='utf-8')
    freq_dict = {}
    for l in dic_file:
        freq_dict[l.split(',')[0]] = l.split(',')[2].strip()
    dic_file.close()
    #print("freq_dict:",freq_dict)
    return freq_dict


def find_word_in_dict(s):
    """
    在字典中查找候选词
    :param s: 输入句子
    :return: 返回字典==>"词:词频|候选左邻词1/候选左邻词2"
    """
    print("========================在字典中查找候选词===================================")
    freq_dict = load_dict()
    result = {}
    for index in range(0, len(s)):  # 遍历所有字
        for wordLen in range(0, len(s) - index):  # 遍历该字的所有可能词
            seg_word = s[index:index + wordLen + 1]
            if seg_word in freq_dict.keys():
                # 找到候选词，找其左邻词
                left_words = ''
                for word_len in range(index, 0, -1):  # 在之前的候选词列表里找左邻词（最大词长开始）
                    for k in result.keys():
                        if s[index - word_len:index] == k.split('-')[1]:
                            left_words += str(index - word_len) + '-' + s[index - word_len:index] + '/'
                # 返回候选词及其语料库词频和候选左邻词
                result[str(index) + '-' + seg_word] = freq_dict[seg_word] + '|' + left_words
                print("result:",result)    
    return result


def cl_probability(words_dict):
    """
    计算累加概率并选择最佳左邻词
    :param words_dict: "词:词频|候选左邻词1/候选左邻词2"
    :return:返回新字典==>"词:累计概率|最佳左邻词"
    """
    print("========================计算累加概率并选择最佳左邻词===================================")
    for k, v in words_dict.items():
        freq = v.split('|')[0][:-1]
        left_words = v.split('|')[1]
        if left_words == '':
            continue
        else:
            left_word = left_words.split("/")
            max_left_p = 0.0
            which_word = ''
            for num in range(0, len(left_word) - 1):
                curr_left_word_p = float(words_dict[left_word[num]].split('|')[0][:-1])
                if curr_left_word_p > max_left_p:  # 比较当前左邻词的累计概率
                    max_left_p = curr_left_word_p
                    which_word = left_word[num]
            curr_max_p = float(max_left_p) * float(freq)
            # 用最大累计概率替换原来的词频,用最佳左邻词替换候选左邻词
            words_dict[k] = v.replace(freq, str(curr_max_p)).replace(left_words, which_word)
        print("words_dict:",words_dict)
    return words_dict


def seg(sentence):
    """
    接收输入，调用函数并输出
    :param sentence:
    :return: 分词后的句子
    """
    words_dict = find_word_in_dict(sentence)
    best_words_dict = cl_probability(words_dict)
    seg_line = ''
    keys = list(best_words_dict.keys())
    key = keys[-1]
    print("========================分词后的句子===================================")
    while key != '':
        seg_line = key.split('-')[1] + '/ ' + seg_line
        key = best_words_dict[key].split('|')[1]
        print("seg_line:",seg_line)
    return seg_line


if __name__ == '__main__':
    #print("概率最大化分词：")
    #input_str = input()结合成分子时
    input_str = "结合成分子时"
    print(seg(input_str))
# Out:
# ========================在字典中查找候选词===================================
# result: {'0-结': '0.0037%|'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/'}
# result: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '0.0049%|0-结/', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# ========================计算累加概率并选择最佳左邻词===================================
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '0.0006%|0-结/', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.0423%|0-结合/1-合/', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '0.0023%|0-结合/1-合/', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '8.119e-05%|0-结合', '3-分': '0.0312%|1-合成/2-成/', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '8.119e-05%|0-结合', '3-分': '4.6587528e-05%|2-成', '3-分子': '0.0038%|1-合成/2-成/', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '8.119e-05%|0-结合', '3-分': '4.6587528e-05%|2-成', '3-分子': '5.674122e-06%|2-成', '4-子': '0.0010%|2-成分/3-分/', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '8.119e-05%|0-结合', '3-分': '4.6587528e-05%|2-成', '3-分子': '5.674122e-06%|2-成', '4-子': '8.119e-08%|2-成分', '5-时': '0.1043%|3-分子/4-子/'}
# words_dict: {'0-结': '0.0037%|', '0-结合': '0.0353%|', '1-合': '1.813e-05%|0-结', '1-合成': '2.22e-06%|0-结', '2-成': '0.00149319%|0-结合', '2-成分': '8.119e-05%|0-结合', '3-分': '4.6587528e-05%|2-成', '3-分子': '5.674122e-06%|2-成', '4-子': '8.119e-08%|2-成分', '5-时': '5.918109246e-07%|3-分子'}
# ========================分词后的句子===================================
# seg_line: 时/
# seg_line: 分子/ 时/
# seg_line: 成/ 分子/ 时/
# seg_line: 结合/ 成/ 分子/ 时/
# 结合/ 成/ 分子/ 时/

# %%
if __name__ == '__main__':
    #print("概率最大化分词：")
    #input_str = input()结合成分子时
    input_str = "使用户满意"
    print(seg(input_str))
# Out:
# ========================在字典中查找候选词===================================
# result: {'0-使': '0.1174%|'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/', '1-用户': '0.0092%|0-使/'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/', '1-用户': '0.0092%|0-使/', '2-户': '0.0231%|0-使用/1-用/'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/', '1-用户': '0.0092%|0-使/', '2-户': '0.0231%|0-使用/1-用/', '3-满': '0.0114%|1-用户/2-户/'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/', '1-用户': '0.0092%|0-使/', '2-户': '0.0231%|0-使用/1-用/', '3-满': '0.0114%|1-用户/2-户/', '3-满意': '0.0078%|1-用户/2-户/'}
# result: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.0688%|0-使/', '1-用户': '0.0092%|0-使/', '2-户': '0.0231%|0-使用/1-用/', '3-满': '0.0114%|1-用户/2-户/', '3-满意': '0.0078%|1-用户/2-户/', '4-意': '0.0044%|3-满/'}
# ========================计算累加概率并选择最佳左邻词===================================
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.0092%|0-使/', '2-户': '0.0231%|0-使用/1-用/', '3-满': '0.0114%|1-用户/2-户/', '3-满意': '0.0078%|1-用户/2-户/', '4-意': '0.0044%|3-满/'}
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.00108008%|0-使', '2-户': '0.0231%|0-使用/1-用/', '3-满': '0.0114%|1-用户/2-户/', '3-满意': '0.0078%|1-用户/2-户/', '4-意': '0.0044%|3-满/'}
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.00108008%|0-使', '2-户': '0.00042965999999999995%|0-使用', '3-满': '0.0114%|1-用户/2-户/', '3-满意': '0.0078%|1-用户/2-户/', '4-意': '0.0044%|3-满/'}
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.00108008%|0-使', '2-户': '0.00042965999999999995%|0-使用', '3-满': '1.2312912e-05%|1-用户', '3-满意': '0.0078%|1-用户/2-户/', '4-意': '0.0044%|3-满/'}
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.00108008%|0-使', '2-户': '0.00042965999999999995%|0-使用', '3-满': '1.2312912e-05%|1-用户', '3-满意': '8.424624e-06%|1-用户', '4-意': '0.0044%|3-满/'}
# words_dict: {'0-使': '0.1174%|', '0-使用': '0.0186%|', '1-用': '0.00807712%|0-使', '1-用户': '0.00108008%|0-使', '2-户': '0.00042965999999999995%|0-使用', '3-满': '1.2312912e-05%|1-用户', '3-满意': '8.424624e-06%|1-用户', '4-意': '5.41768128e-08%|3-满'}
# ========================分词后的句子===================================
# seg_line: 意/
# seg_line: 满/ 意/
# seg_line: 用户/ 满/ 意/
# seg_line: 使/ 用户/ 满/ 意/
# 使/ 用户/ 满/ 意/

# %%
if __name__ == '__main__':
    #print("概率最大化分词：")
    #input_str = input()结合成分子时
    input_str = "他说的确实在理"
    print(seg(input_str))
# Out:
# ========================在字典中查找候选词===================================
# result: {'0-他': '0.2519%|'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/'}
# result: {'0-他': '0.2519%|', '1-说': '0.2280%|0-他/', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# ========================计算累加概率并选择最佳左邻词===================================
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '4.8586%|1-说/', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.0024%|1-说/', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0027%|2-的/', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0047%|2-的/', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '0.0028%|2-的确/3-确/', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '2.1095797881312004e-06%|3-确', '4-实在': '0.0030%|2-的确/3-确/', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '2.1095797881312004e-06%|3-确', '4-实在': '2.2602640587120003e-06%|3-确', '5-在': '1.0722%|3-确实/4-实/', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '2.1095797881312004e-06%|3-确', '4-实在': '2.2602640587120003e-06%|3-确', '5-在': '0.001406202355756757%|3-确实', '5-在理': '0.0001%|3-确实/4-实/', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '2.1095797881312004e-06%|3-确', '4-实在': '2.2602640587120003e-06%|3-确', '5-在': '0.001406202355756757%|3-确实', '5-在理': '1.3115112439440001e-07%|3-确实', '6-理': '0.0029%|4-实在/5-在/'}
# words_dict: {'0-他': '0.2519%|', '1-说': '0.057433200000000004%|0-他', '2-的': '0.27904494552000003%|1-说', '2-的确': '0.00013783968%|1-说', '3-确': '0.0007534213529040001%|2-的', '3-确实': '0.0013115112439440002%|2-的', '4-实': '2.1095797881312004e-06%|3-确', '4-实在': '2.2602640587120003e-06%|3-确', '5-在': '0.001406202355756757%|3-确实', '5-在理': '1.3115112439440001e-07%|3-确实', '6-理': '4.077986831694595e-06%|5-在'}
# ========================分词后的句子===================================
# seg_line: 理/
# seg_line: 在/ 理/
# seg_line: 确实/ 在/ 理/
# seg_line: 的/ 确实/ 在/ 理/
# seg_line: 说/ 的/ 确实/ 在/ 理/
# seg_line: 他/ 说/ 的/ 确实/ 在/ 理/
# 他/ 说/ 的/ 确实/ 在/ 理/

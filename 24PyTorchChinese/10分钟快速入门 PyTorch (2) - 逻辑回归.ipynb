# %% [markdown]
# http://www.pytorchtutorial.com/10-minute-pytorch-2/

# %% [markdown]
# Finish 1000 epoch, Loss: 0.256448, Acc: 0.929517
# Test Loss: 0.267056, Acc: 0.923900
# Time:7.7 s

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import datasets
import time
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# 定义超参数
batch_size = 32
learning_rate = 1e-3 # 0.001 学习速率
num_epoches = 10 # 训练次数

# %%
# 下载训练集 MNIST 手写数字训练集
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 定义 Logistic Regression 模型
class Logstic_Regression(nn.Module):
    def __init__(self, in_dim, n_class):
        super(Logstic_Regression, self).__init__()
        self.logstic = nn.Linear(in_dim, n_class)

    def forward(self, x):
        out = self.logstic(x)
        return out


model = Logstic_Regression(28 * 28, 10)  # 图片大小是28x28，10类（十种数字）
# use_gpu = torch.cuda.is_available()  # 判断是否有GPU加速
# if use_gpu:
#     model = model.cuda()

# %%
# 定义loss和optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
# 开始训练
for epoch in range(num_epoches):
    print('*' * 10)
    print('epoch {}'.format(epoch + 1))
    since = time.time()
    running_loss = 0.0
    running_acc = 0.0
    for i, data in enumerate(train_loader, 1):
        img, label = data
        img = img.view(img.size(0), -1)  # 将图片展开成 28x28
#         if use_gpu:
#             with torch.no_grad():
#                 img = img.cuda()            
#                 label = label.cuda()
#         else:
#             with torch.no_grad():
#                 img = img            
#                 label = label
        # 向前传播
        out = model(img)
        loss = criterion(out, label)
        running_loss += loss.item() * label.size(0)
        _, pred = torch.max(out, 1)
        num_correct = (pred == label).sum()
        running_acc += num_correct.item()
        # 向后传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if i % 300 == 0:
            print('[{}/{}] Loss: {:.6f}, Acc: {:.6f}'.format(epoch + 1, num_epoches, running_loss / (batch_size * i),
                running_acc / (batch_size * i)))
    print('Finish {} epoch, Loss: {:.6f}, Acc: {:.6f}'.format(epoch + 1, running_loss / (len(train_dataset)), running_acc / (len(train_dataset))))
    model.eval()
    eval_loss = 0.
    eval_acc = 0.
    
    for data in test_loader:
        
        img, label = data
        img = img.view(img.size(0), -1)
#         if use_gpu:
#             with torch.no_grad():
#                 img = img.cuda()            
#                 label = label.cuda()
#         else:
#             with torch.no_grad():
#                 img = img            
#                 label = label
        out = model(img)
        
#       输出认错的字符，看看长什么样 （仅看看每组的第一个数，否则太多了）   
        ll = label[0].numpy()
        aa = out[0].detach().numpy()
        bb = aa.tolist()
        cc = bb.index(max(bb))
        if ll != cc:
            print('-' * 10)
            print('正确值：',ll)
            print('误以为：',cc)
            one_pic_arr = np.reshape(img[0], (28, 28))
            pic_matrix = np.matrix(one_pic_arr, dtype="float")
            plt.imshow(pic_matrix)
            plt.show()
       
        
        loss = criterion(out, label)
        eval_loss += loss.item() * label.size(0)
        _, pred = torch.max(out, 1)
        num_correct = (pred == label).sum()
        eval_acc += num_correct.item()
    print('Test Loss: {:.6f}, Acc: {:.6f}'.format(eval_loss / (len(test_dataset)), eval_acc / (len(test_dataset))))
    print('Time:{:.1f} s'.format(time.time() - since))
    print()
# Out:
# **********
# epoch 1
# [1/10] Loss: 0.363658, Acc: 0.898958
# [1/10] Loss: 0.367572, Acc: 0.899479
# [1/10] Loss: 0.361401, Acc: 0.901944
# [1/10] Loss: 0.359397, Acc: 0.902760
# [1/10] Loss: 0.359944, Acc: 0.901854
# [1/10] Loss: 0.361732, Acc: 0.901146
# Finish 1 epoch, Loss: 0.362970, Acc: 0.900683
# ----------
# 正确值： 9
# 误以为： 1
# ----------
# 正确值： 5
# 误以为： 0
# ----------
# 正确值： 9
# 误以为： 8
# ----------
# 正确值： 8
# 误以为： 5
# ----------
# 正确值： 9
# 误以为： 4
# ----------
# 正确值： 8
# 误以为： 5
# ----------
# 正确值： 4
# 误以为： 9
# ----------
# 正确值： 2
# 误以为： 1
# ----------
# 正确值： 9
# 误以为： 5
# ----------
# 正确值： 2
# 误以为： 0
# ----------
# 正确值： 7
# 误以为： 2
# ----------
# 正确值： 8
# 误以为： 3
# ----------
# 正确值： 8
# 误以为： 0
# ----------
# 正确值： 5
# 误以为： 8
# ----------
# 正确值： 3
# 误以为： 2
# ----------
# 正确值： 7
# 误以为： 1
# ----------
# 正确值： 6
# 误以为： 4
# ----------
# 正确值： 5
# 误以为： 8
# ----------
# 正确值： 7
# 误以为： 3
# ----------
# 正确值： 9
# 误以为： 4
# ----------
# 正确值： 9
# 误以为： 7
# ----------
# 正确值： 3
# 误以为： 0
# ----------
# ...

# %%
from datetime import datetime

now = datetime.now()

now
# Out:
# datetime.datetime(2018, 3, 21, 20, 29, 9, 715780)

# %%
now.year, now.month, now.day
# Out:
# (2018, 3, 21)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)

# %%
delta
# Out:
# datetime.timedelta(926, 56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
from datetime import timedelta
start = datetime(2011, 1, 7)
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %% [markdown]
# ![](https://upload-images.jianshu.io/upload_images/7178691-4af261a305a70aeb.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/554)

# %% [markdown]
# # 字符串和datetime的相互转换

# %%
stamp = datetime(2011, 1, 3)

# %%
stamp
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime('%Y-%m-%d')
# Out:
# '2011-01-03'

# %% [markdown]
# ![](https://upload-images.jianshu.io/upload_images/7178691-de0181e1f6b45eaf.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/554)

# %%
value = '2018-03-21'

# %%
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2018, 3, 21, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011']
[datetime.strptime(x, '%m/%d/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
from dateutil.parser import parse
parse('2011-01-03')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
parse('Jan 31, 1997 10:45 PM')
# Out:
# datetime.datetime(1997, 1, 31, 22, 45)

# %%
 parse('6/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 6, 0, 0)

# %%
datestrs = ['2011-07-06 12:00:00', '2011-08-06 00:00:00']
import pandas as pd
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### NaT（Not a Time）是pandas中时间戳数据的null值。

# %%
idx = pd.to_datetime(datestrs + [None])

# %%
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
pd.isnull(idx)
# Out:
# array([False, False,  True], dtype=bool)

# %% [markdown]
# ![](https://upload-images.jianshu.io/upload_images/7178691-cf0119398273e2b0.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/554)

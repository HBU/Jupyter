# %%
from pyecharts import Map

value = [139, 173, 732, 630, 867]
attr = ['竞秀区', '莲池区', '徐水区', '满城区', '清苑区']
map = Map("保定地图示例", width=1000, height=600)
map.add("", attr, value, maptype='保定',is_label_show=True, is_visualmap=True, visual_text_color='#000',visual_range=[139,867])
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'bao3_ding4': '/nbextensions/echarts-china-cities-js/he2_bei3_bao3_ding4'
#         }
#     });
# </script>
#     <div id="6d609b74ac0e4f9abbd836d1dd0d897e" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'bao3_ding4'], function(echarts) {
#
# var myChart_6d609b74ac0e4f9abbd836d1dd0d897e = echarts.init(document.getElementById('6d609b74ac0e4f9abbd836d1dd0d897e'), null, {renderer: 'canvas'});
# var option_6d609b74ac0e4f9abbd836d1dd0d897e = {
#     "title": [
#         {
#             "text": "\u4fdd\u5b9a\u5730\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
# ...

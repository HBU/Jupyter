# %%
from pyecharts import Bar
import requests
import re
import time
from lxml import html
from selenium import webdriver
from pyecharts import Map

r = requests.get(url='http://www.sohu.com/a/223885358_118392')    # 最基本的GET请求
# time.sleep(60)
html = r.text
content = re.findall(u'<p>([\u2E80-\u9FFF]{2,3})[u"市"u"省"u"特"u"壮"u"回"u"维"u"自"u"人"].{0,6}\uff08(\d*)\u540d\uff09 </p>.*?<p>(.*?)</p>', html, re.S)
import pandas as pd
# 取地区，姓名，性别，族
data = [(_[0],_[2]) for _ in content]
def get_locality_name_sex_race(param):
    print('get_locality_name_sex_race')
    locality = param[0]    
    for el in param[1].split(u'、'):# '、'分割姓名
        temp = re.split(u'\uff08|\uff0c|\uff09', el)
        length = len(temp)
        if length == 1: # 只有名字，加上： 男 汉族
            temp += [u'男', u'汉族']
        elif length == 3: # 有名字 有性别，加上 汉族
            if len(temp[1]) == 1:
                temp[2] = u'汉族'
            else: # 有名字 有民族，加上 男
                temp[2] = temp[1]
                temp[1] = u'男'
        elif length == 4:# ？
            temp.pop()
            if u'族' not in temp[2]:
                temp[2] = u'汉族'
                
        df.loc[df.shape[0]] = [locality]+temp
df = pd.DataFrame(columns=('locality', 'name', 'sex', 'race'))#生成空的pandas表
list(map(get_locality_name_sex_race, data))
df.head(10)
# Out:
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
# get_locality_name_sex_race
#   locality name sex race
# 0       北京  于志刚   男   汉族
# 1       北京  马一德   男   汉族
# 2       北京   王全   男   汉族
# 3       北京   王铮   男   汉族
# 4       北京  方复全   男   汉族
# 5       北京   厉莉   女   汉族
# 6       北京  田春艳   女   满族
# 7       北京  冯乐平   女   汉族
# 8       北京   任鸣   男   汉族
# 9       北京   伊彤   女   满族

# %%
df['surname'] = [_[0] for _ in df['name']]
surname_Data = df['surname'].value_counts()
bar = Bar("", "", width=800, height=400)
bar.add("", surname_Data.index.values.tolist()[0:30],
        surname_Data.values.tolist()[0:30], is_label_show=True, 
        is_legend_show=True,is_more_utils=True)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4b12318cda8e4d7795f60b0fac51b4f0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4b12318cda8e4d7795f60b0fac51b4f0 = echarts.init(document.getElementById('4b12318cda8e4d7795f60b0fac51b4f0'), null, {renderer: 'canvas'});
# var option_4b12318cda8e4d7795f60b0fac51b4f0 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 4858726,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 249,
#                 203,
#                 193,
#                 147,
#                 124,
#                 94,
#                 65,
#                 53,
#                 52,
#                 51,
#                 51,
#                 50,
#                 44,
#                 44,
#                 37,
#                 34,
#                 33,
#                 30,
#                 29,
#                 29,
#                 24,
#                 24,
#                 24,
#                 24,
#                 23,
#                 22,
#                 20,
#                 19,
#                 19,
#                 18
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4858726
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u738b",
#                 "\u674e",
#                 "\u5f20",
#                 "\u5218",
#                 "\u9648",
#                 "\u6768",
#                 "\u5434",
#                 "\u9ec4",
#                 "\u5468",
#                 "\u5f90",
#                 "\u9a6c",
#                 "\u8d75",
#                 "\u5b59",
#                 "\u90ed",
#                 "\u6731",
#                 "\u9ad8",
#                 "\u80e1",
#                 "\u8bb8",
#                 "\u7f57",
#                 "\u90d1",
#                 "\u5b8b",
#                 "\u4f55",
#                 "\u6797",
#                 "\u4e8e",
#                 "\u97e9",
#                 "\u51af",
#                 "\u8881",
#                 "\u8c22",
#                 "\u4e01",
#                 "\u6c88"
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_4b12318cda8e4d7795f60b0fac51b4f0.setOption(option_4b12318cda8e4d7795f60b0fac51b4f0);
#
#     });
# </script>

# %%
from pyecharts import WordCloud

wordcloud = WordCloud(width=1200, height=600)
wordcloud.add("", surname_Data.index.values.tolist(),
              surname_Data.values.tolist(), word_size_range=[20, 100])
wordcloud.render()
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="caaa64651c8042729a2f61fc5b2b0c73" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_caaa64651c8042729a2f61fc5b2b0c73 = echarts.init(document.getElementById('caaa64651c8042729a2f61fc5b2b0c73'), null, {renderer: 'canvas'});
# var option_caaa64651c8042729a2f61fc5b2b0c73 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3426265,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u738b",
#                     "value": 249,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,74,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u674e",
#                     "value": 203,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,62,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f20",
#                     "value": 193,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,114,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5218",
#                     "value": 147,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,95,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9648",
#                     "value": 124,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,63,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6768",
#                     "value": 94,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,93,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5434",
#                     "value": 65,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,18,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,53,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5468",
#                     "value": 52,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,13,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f90",
#                     "value": 51,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,147,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9a6c",
#                     "value": 51,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,39,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d75",
#                     "value": 50,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,52,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b59",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,84,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u90ed",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,38,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6731",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,60,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ad8",
#                     "value": 34,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,123,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u80e1",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,25,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bb8",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,153,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f57",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,0,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u90d1",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,136,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b8b",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,46,18)"
#                         }
#                     }

# %% [markdown]
# https://www.jianshu.com/p/66f2627a8092

# %% [markdown]
# # 爬取代表数据

# %%
import requests
import re
import time
from lxml import html
from selenium import webdriver
r = requests.get(url='http://www.sohu.com/a/223885358_118392')    # 最基本的GET请求
time.sleep(60)
html = r.text

# %% [markdown]
# # 正则表达式提取需要的数据

# %%
content = re.findall(u'<p>([\u2E80-\u9FFF]{2,3})[u"市"u"省"u"特"u"壮"u"回"u"维"u"自"u"人"].{0,6}\uff08(\d*)\u540d\uff09 </p>.*?<p>(.*?)</p>', html, re.S)

# %%
from pyecharts import Map
data = [_[0:2] for _ in content]

# %%
map = Map("人大代表分布", title_pos="center",width=800, height=500)
attr, value =map.cast(data)
attr[-1] = u"南海诸岛"
map.add("", attr, value, maptype='china',
        is_label_show=True,label_pos="inside",label_text_color="#000",
        is_visualmap=True, visual_text_color='#000', visual_range=[12, 172],visual_range_text=['低','高'],
       visual_pos = [500,500])
#map.show_config()
# map.render()
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="d39c7f6317644ba3982ea6f763e02643" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_d39c7f6317644ba3982ea6f763e02643 = echarts.init(document.getElementById('d39c7f6317644ba3982ea6f763e02643'), null, {renderer: 'canvas'});
# var option_d39c7f6317644ba3982ea6f763e02643 = {
#     "title": [
#         {
#             "text": "\u4eba\u5927\u4ee3\u8868\u5206\u5e03",
#             "subtext": "",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3388891,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": "55"
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": "42"
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": "125"
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": "70"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": "58"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": "102"
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": "64"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": "92"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": "59"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": "150"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": "94"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": "113"
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": "69"
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": "81"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": "175"
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": "172"
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": "118"
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": "118"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": "162"
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": "89"
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": "25"
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": "61"
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": "148"
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": "72"
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": "91"
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": "20"
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": "68"
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": "54"
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": "21"
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": "21"
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": "61"
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": "36"
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": "12"
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": "13"
#                 },
#                 {
#                     "name": "\u5357\u6d77\u8bf8\u5c9b",
#                     "value": "269"
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 12,
#         "max": 172,
#         "text": [
#             "\u9ad8",
#             "\u4f4e"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,

# %% [markdown]
# # 貌似是数据量太大，在线不好使，导出到HTML吧

# %%
import requests
import pandas as pd
import numpy as np
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'to_excel does not support emoj'

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    20448                     to_excel does not support emoj
# 1    20447  UnicodeDecodeError when import sas7bdat with s...
# 2    20446  scatter plot and hexbin plot lose x-axis when ...
# 3    20445  pd.to_datetime, unit='s'  much slower for floa...
# 4    20444      API: Preserve int columns in to_dict('index')
# 5    20443           DOC: update the Series.between docstring
# 6    20442                     BUG: None is not equal to None
# 7    20441  Series.__setitem__ on DatetimeTZ values with t...
# 8    20439  Categorical.__setitem__ doesn't handle setting...
# 9    20438                          iloc boolean mask setitem
# 10   20437  BUG: Patch for skipping seek() when loading Ex...
# 11   20436  read_csv converters behaves inexpectantly with...
# 12   20435  feature request: efficient "random access" Dat...
# 13   20434  UnsupportedOperation 'seek' when loading excel...
# 14   20432  BUG: DataFrame/Series.loc improperly allows lo...
# 15   20430          DOC: update the DataFrame.stack docstring
# 16   20429  read_excel with dtype=str converst empty cells...
# 17   20427  Resampling operations on float32 masked array ...
# 18   20424                       DOC: Update missing_data.rst
# 19   20423            Bins from pd.cut are not of equal width
# 20   20422  BUG: dropna() on single column timezone-aware ...
# 21   20421  API: Allow MultiIndex.rename() to accept a dic...
# 22   20420  Inconsistent groupby-apply output shape and ra...
# 23   20419  Deprecate Series.strides, .base, .data, .items...
# 24   20418             Legend of point-style items go missing
# 25   20417  Add an alias 'stable' for 'mergesort' in sort_...
# 26   20416  API: groupby with categoricals inconsistent wi...
# 27   20415  DOC: Update ops.py to add examples to docstrin...
# 28   20414  API: Inconsistent behavior with setting slices...
# 29   20413   DOC : update the pandas.Period.weekday docstring
#
#                                                labels state
# 0   [{'id': 307649777, 'url': 'https://api.github....  open
# 1                                                  []  open
# 2   [{'id': 2413328, 'url': 'https://api.github.co...  open
# 3   [{'id': 195647922, 'url': 'https://api.github....  open
# 4                                                  []  open
# 5                                                  []  open
# 6   [{'id': 76811, 'url': 'https://api.github.com/...  open
# 7   [{'id': 195647930, 'url': 'https://api.github....  open
# 8   [{'id': 78527356, 'url': 'https://api.github.c...  open
# 9   [{'id': 76811, 'url': 'https://api.github.com/...  open
# 10                                                 []  open
# 11                                                 []  open
# 12                                                 []  open
# 13  [{'id': 49254273, 'url': 'https://api.github.c...  open
# 14  [{'id': 76865106, 'url': 'https://api.github.c...  open
# 15                                                 []  open
# 16                                                 []  open
# 17                                                 []  open
# 18                                                 []  open
# 19                                                 []  open
# 20                                                 []  open
# 21                                                 []  open
# 22                                                 []  open
# 23  [{'id': 35818298, 'url': 'https://api.github.c...  open
# 24                                                 []  open
# 25  [{'id': 76812, 'url': 'https://api.github.com/...  open
# 26  [{'id': 35818298, 'url': 'https://api.github.c...  open
# 27                                                 []  open
# 28                                                 []  open
# 29  [{'id': 134699, 'url': 'https://api.github.com...  open
